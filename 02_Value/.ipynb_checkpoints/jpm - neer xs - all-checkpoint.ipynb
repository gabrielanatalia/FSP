# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = [x for x in ALL_FX if x not in ["USDMYR", "USDCNH"]]
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
                   asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=130, rebalance_period="daily",
                   sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=130,
                   portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=260)

# %% [markdown]
# # Other Data

# %%
neer = read_prices("../../Dymon/Code Data/NEER.csv")

# %%
neer.columns = [x[0] for x in neer.columns]

# %%
all_neer = neer[[("JBDN"+x+" Index") for x in [x[3:] for x in universe]]]
all_neer.columns = universe

# %%
all_neer_cleaned = all_neer.pipe(fill_date, True).pipe(omit_trailing_na)

# %% [markdown]
# # Data Integrity

# %%
msmx(all_neer)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
mag = all_neer_cleaned.pipe(demean_pct, 252*5)
sig = mag.pipe(omit_leading_na,"any").pipe(high_minus_low)

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings,
                    settings_inject={"use_cov":False})
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.027138032723410754
# Vol       : 0.10154581333986114
# SR        : 0.26724915415846
# Max DD    : -28.79
#
# C Returns : 0.02223123288956927
# C SR      : 0.26157754136255523
# C Max DD  : -27.26
#
# Hit rate  : 0.506
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.02

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
# C:\Users\vin_s\National University of Singapore\FSP Dymon AY21 22 Term 1 - Documents\Codebase\02_Value\..\genesis.py:797: RuntimeWarning: invalid value encountered in double_scalars
#   return (ret - rf).mean() * np.sqrt(obs_per_year) / ret.std()
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return    -0.061205   -0.631813    0.385773     1.65895
# sharpe               -0.017229   -0.209545    0.176136    0.480921
# dollar_sharpe        -0.035367   -0.225347    0.167589    0.483808
# trade_sharpe         -0.512101   -0.487746   -0.237483    0.263114
# long_sharpe          -0.554565   -0.588525   -0.384204    1.265052
# short_sharpe         -0.428896   -0.333421   -0.161387   -0.279405
# sortino              -0.012033    -0.11593    0.079947    0.313923
# max_drawdown             -9.73  -14.163838   -7.054127  -11.223364
# max_drawdown_start  2010-07-19  2005-05-26  2008-12-05  2008-03-13
# max_drawdown_end    2016-01-15  2016-01-19  2010-06-07  2010-05-18
#
#                         USDJPY      USDNZD      USDSEK      USDNOK  \
# annualized_return    -1.678775    1.312036    0.080356   -0.723752
# sharpe               -0.439146     0.50885    0.048912   -0.328305
# dollar_sharpe        -0.461961    0.498051    0.044634   -0.331925
# trade_sharpe         -0.653889    0.192113   -0.953261   -0.838515
# long_sharpe          -0.254009    0.298596   -0.336503   -0.122958
# short_sharpe         -0.933761   -0.244722   -2.834697   -0.871967
# sortino              -0.294509    0.263553    0.015231   -0.120205
# max_drawdown        -31.732047   -6.699063   -3.729118  -11.873412
# max_drawdown_start  2006-05-16  2013-07-05  2011-12-19  2008-09-11
# max_drawdown_end    2015-06-05  2014-07-09  2013-02-13  2016-01-06
#
#                         USDCHF      USDSGD      USDTHB      USDTWD  \
# annualized_return     0.574913     0.26444   -1.543628    0.640814
# sharpe                 0.16584    0.115046    -0.71919    0.346321
# dollar_sharpe         0.153696    0.091157   -0.751001    0.355645
# trade_sharpe         -0.003343     0.02532   -1.694793    0.555378
# long_sharpe          -0.061589    0.025346   -1.703064    1.051402
# short_sharpe          0.505634         NaN   -1.645978    0.455815
# sortino               0.109306    0.047628   -0.237179    0.148675
# max_drawdown        -18.866947   -10.10581  -22.691183    -3.46031
# max_drawdown_start  2010-06-07  2008-11-19  2005-05-10  2006-12-05
# max_drawdown_end    2011-08-09  2011-11-30  2008-03-07  2007-05-23
#
#                         USDKRW      USDPHP      USDINR      USDIDR
# annualized_return     -0.13544    0.925296    0.442752    1.210514
# sharpe                -0.03524    0.360985    0.142095    0.348383
# dollar_sharpe        -0.057961    0.346178    0.122537    0.329481
# trade_sharpe         -0.080589    0.393866    0.114182    0.370572
# long_sharpe          -0.024067    0.317462         NaN         NaN
# short_sharpe         -0.149365    0.630797    0.114182    0.370572
# sortino              -0.023111    0.169403    0.078279     0.19272
# max_drawdown        -18.657782   -6.763183  -14.712727   -9.156003
# max_drawdown_start  2005-07-06  2006-05-08  2011-08-01  2013-06-11
# max_drawdown_end    2008-10-08  2008-02-27  2013-09-03  2015-09-28

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Other Freq

# %%
monthly_bt = Backtest(signal = sig, 
                      asset_returns = total_returns, 
                      tcost = abs(total_returns*0), 
                      settings = settings,
                      settings_inject={"rebalance_period":"monthly"})
monthly_bt.run()
get_summary(monthly_bt)
plot_bt(monthly_bt)
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Returns   : 0.028554278514485054
# Vol       : 0.10371899491658995
# SR        : 0.27530423465295045
# Max DD    : -39.82
#
# C Returns : 0.023453979954257704
# C SR      : 0.27723708129312485
# C Max DD  : -34.86
#
# Hit rate  : 0.499
# W | N | L : 0.5 | 0.0 | 0.5
# W/L Ratio : 0.99

# %%
bts = [Backtest(signal = sig, 
               asset_returns = total_returns, 
               tcost = abs(total_returns*0), 
               settings = settings,
               settings_inject = {"rebalance_period":t}) for t in ["monday","tuesday", "wednesday",
                                                                   "thursday", "friday", "monthly"]]
for bt in bts:
  bt.run()

gen_plot_rtn(pd.concat([x.model_rtn.rename(x.rebalance_period) for x in [daily_bt]+bts], axis=1))
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/jpm_cpi_xs_all_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/jpm_cpi_xs_all_daily.p", "rb"))

# pickle.dump(bts[-1], open("../BT/jpm_cpi_xs_all_monthly.p", "wb"))
# monthly_bt = pickle.load(open("../BT/jpm_cpi_xs_all_monthly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %%
# sig = -1 * sig.pipe(omit_leading_na,"any").pipe(high_minus_low) 


# sig = asia_reer_cpi_cleaned.ffill().pct_change().pipe(zscore, 252*5, 252*3).apply(hold_until_flip) * -1
# sig = sig.pipe(demean_xs).pipe(top_bottom_xs)
# sig[abs(sig) < 0.25] = 0
# sig = CAP(sig, 2.5)
