# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *

# %%
universe = G10_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
                   asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=130, rebalance_period="daily",
                   sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=130,
                   portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=260)

# %% [markdown]
# # Other Data

# %%
reer_ppi = read_prices("../../Dymon/Code Data/REER_PPI.csv")

# %%
reer_ppi.columns = [x[0] for x in reer_ppi.columns]

# %%
g10_reer_ppi = reer_ppi[[("JBDP"+x+" Index") for x in [x[3:] for x in universe]]]
g10_reer_ppi.columns = universe

# %%
g10_reer_ppi_cleaned = g10_reer_ppi.pipe(fill_date, True).pipe(omit_trailing_na)

# %% [markdown]
# # Data Integrity

# %%
msmx(g10_reer_ppi)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
mag = g10_reer_ppi_cleaned.pipe(demean_pct, 252*5, 252)
sig = abs(mag) * mag.pipe(omit_leading_na,"any").pipe(high_minus_low) * -1

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings,
                    settings_inject={"use_cov":False})
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : -0.016443858613043892
# Vol       : 0.10892369813545727
# SR        : -0.15096676751274407
# Max DD    : -73.52
#
# C Returns : -0.02211372433296617
# C SR      : -0.2603233651731328
# C Max DD  : -56.0
#
# Hit rate  : 0.474
# W | N | L : 0.47 | 0.0 | 0.53
# W/L Ratio : 0.9

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return     0.081718    0.599796    0.358297    1.526879
# sharpe                0.021023      0.3816     0.13521    0.361667
# dollar_sharpe         0.007837    0.370694    0.131543    0.362491
# trade_sharpe         -0.262477    0.752356   -0.004064    0.292682
# long_sharpe          -0.315368    1.019513    -1.03386    1.086648
# short_sharpe          0.095071    0.659052    0.542866   -0.030975
# sortino               0.012034    0.109645     0.05148    0.203201
# max_drawdown        -16.519675   -7.464605   -14.96469  -20.545181
# max_drawdown_start  2003-08-27  2014-08-28  2003-03-21  2008-07-15
# max_drawdown_end    2007-07-25  2016-01-19  2010-06-07  2010-05-18
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return    -2.097068   -1.801638    0.463435   -1.119781    0.433995
# sharpe               -0.331938   -0.355829     0.38824   -0.332632    0.121773
# dollar_sharpe        -0.331053   -0.454178    0.383395   -0.386772    0.112133
# trade_sharpe         -0.414985    -0.65019    0.677524   -0.758208    0.050348
# long_sharpe          -0.173801   -0.711475         NaN     -0.8639    0.041041
# short_sharpe         -0.463583    1.113058    0.677524   -0.593301    0.090148
# sortino              -0.200053   -0.195644    0.087177   -0.165429    0.046253
# max_drawdown        -57.079429  -50.956292   -3.583844  -27.591982  -26.086906
# max_drawdown_start  2005-01-14  2002-02-05  2001-08-15  2001-07-03  2009-04-20
# max_drawdown_end    2015-06-05  2005-03-18  2001-09-21  2008-05-21  2011-08-09

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Other Freq

# %%
bts = [Backtest(signal = sig, 
               asset_returns = total_returns, 
               tcost = abs(total_returns*0), 
               settings = settings,
               settings_inject = {"rebalance_period":t}) for t in ["monday","tuesday", "wednesday",
                                                                   "thursday", "friday", "monthly"]]
for bt in bts:
  bt.run()
  
gen_plot_rtn(pd.concat([x.model_rtn.rename(x.rebalance_period) for x in [daily_bt]+bts], axis=1))
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/jpm_ppi_xs_g10_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/jpm_ppi_xs_g10_daily.p", "rb"))

# pickle.dump(bts[-1], open("../BT/jpm_ppi_xs_g10_monthly.p", "wb"))
# monthly_bt = pickle.load(open("../BT/jpm_ppi_xs_g10_monthly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %%
# sig = -1 * sig.pipe(omit_leading_na,"any").pipe(high_minus_low) 


# sig = asia_reer_cpi_cleaned.ffill().pct_change().pipe(zscore, 252*5, 252*3).apply(hold_until_flip) * -1
# sig = sig.pipe(demean_xs).pipe(top_bottom_xs)
# sig[abs(sig) < 0.25] = 0
# sig = CAP(sig, 2.5)
