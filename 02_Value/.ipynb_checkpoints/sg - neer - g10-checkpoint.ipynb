# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *

# %%
universe = G10_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %% [markdown]
# # Data integrity

# %% [markdown]
# # Signal

# %%
sig = spot_price_usd[universe].pipe(fill_date).rolling(window = 252*6, min_periods = 252*3).apply(lambda x: (x[-1]/x[0])-1).pipe(demean_xs).pipe(top_bottom_xs).pipe(cap_helper, 0.2).pipe(rolling_mean, 5) * -1

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.04659841921271599
# Vol       : 0.10596385007853298
# SR        : 0.43975770206707765
# Max DD    : -38.7
#
# C Returns : 0.04184674224183183
# C SR      : 0.44029877433001685
# C Max DD  : -33.25
#
# Hit rate  : 0.491
# W | N | L : 0.49 | 0.0 | 0.51
# W/L Ratio : 0.96

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return     1.347618    1.055124   -0.178599    0.924783
# sharpe                0.460968     0.39329   -0.071991    0.166848
# dollar_sharpe         0.453612    0.378647   -0.086201    0.152706
# trade_sharpe          0.580703    0.755262   -0.127567     0.18451
# long_sharpe             0.6332    0.568572    0.406542     1.79623
# short_sharpe          0.976876    1.034846   -0.287983     0.05148
# sortino               0.262241    0.145441   -0.027437    0.093794
# max_drawdown        -10.784224    -7.13143  -14.287324  -21.775081
# max_drawdown_start  2010-07-19  2010-05-20  2013-02-01  2008-07-15
# max_drawdown_end    2012-08-10  2016-01-19  2015-03-13  2010-05-18
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return    -0.363771    0.960022    0.392767   -0.377765    0.982372
# sharpe                -0.04758    0.205069    0.243857   -0.121567    0.206807
# dollar_sharpe        -0.084323    0.193833    0.236604   -0.137123    0.189801
# trade_sharpe          -0.04846    0.265089    0.532256   -0.240195    0.244857
# long_sharpe           1.085344     0.15827    0.281014    0.333727    0.228945
# short_sharpe         -0.397153     1.81528    0.535734   -0.332097    1.692172
# sortino              -0.031073    0.129526     0.07737   -0.045897     0.10792
# max_drawdown        -39.196444  -14.337689   -4.826783  -12.827355  -18.364488
# max_drawdown_start  2004-12-03  2006-06-28  2010-03-12  2014-05-08  2010-02-15
# max_drawdown_end    2007-06-22  2007-07-24  2010-06-07  2016-01-06  2011-08-09

# %%
daily_bt.model_rtn.skew()
# Out:
# 0.5512807126323167

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.04583250762091514
# Vol       : 0.10637468505079045
# SR        : 0.4308591616419979
# Max DD    : -37.84
#
# C Returns : 0.04100556530980398
# C SR      : 0.42829038617629417
# C Max DD  : -32.67
#
# Hit rate  : 0.489
# W | N | L : 0.49 | 0.0 | 0.51
# W/L Ratio : 0.96

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return     1.237346     0.91536   -0.071444    0.903703
# sharpe                0.412215    0.338564   -0.029218    0.163165
# dollar_sharpe         0.403887    0.323476   -0.039622     0.14416
# trade_sharpe          0.548283    0.673394   -0.066421    0.192701
# long_sharpe           0.599491    0.516296    0.780419    1.911157
# short_sharpe          0.959761    0.907491   -0.302304    0.052943
# sortino               0.229535    0.125762   -0.011508    0.091694
# max_drawdown        -12.404009   -7.432074  -12.679505  -21.368533
# max_drawdown_start  2010-05-20  2008-11-20  2013-02-01  2008-07-15
# max_drawdown_end    2012-09-14  2016-01-19  2015-03-13  2010-05-18
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return    -0.266778    0.958287    0.517246   -0.392911    0.864462
# sharpe               -0.034997    0.203305    0.323995   -0.128289    0.181621
# dollar_sharpe        -0.070976    0.194509    0.318449   -0.144218    0.164915
# trade_sharpe          -0.03301    0.248644    0.679139   -0.233849    0.216729
# long_sharpe            1.02963    0.142266   -1.978243    0.013562    0.195578
# short_sharpe         -0.357652    1.778819    0.689818   -0.274871    2.019324
# sortino               -0.02301    0.128169    0.102422   -0.048568    0.095434
# max_drawdown        -38.600442  -14.389105   -4.757778  -12.688506  -19.201012
# max_drawdown_start  2004-12-03  2006-03-28  2010-03-12  2014-05-08  2009-03-13
# max_drawdown_end    2007-06-22  2007-07-24  2010-06-07  2016-01-06  2011-08-09

# %%
plot_bt(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/value_sgneer_g10_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/value_sgneer_g10_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/value_sgneer_g10_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/value_sgneer_g10_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis

# %%
# pf.plot_monthly_returns_dist(bt_obj.model_rtn)
