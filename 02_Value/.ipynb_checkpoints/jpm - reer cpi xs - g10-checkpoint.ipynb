# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = G10_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
                   asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=130, rebalance_period="daily",
                   sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=130,
                   portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=260)

# %% [markdown]
# # Other Data

# %%
reer_cpi = read_prices("../../Dymon/Code Data/REER_CPI.csv")

# %%
reer_cpi.columns = [x[0] for x in reer_cpi.columns]

# %%
g10_reer_cpi = reer_cpi[[("JBDC"+x+" Index") for x in [x[3:] for x in universe]]]
g10_reer_cpi.columns = universe

# %%
g10_reer_cpi_cleaned = g10_reer_cpi.pipe(fill_date, True).pipe(omit_trailing_na)

# %% [markdown]
# # Data Integrity

# %%
msmx(g10_reer_cpi)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
mag = g10_reer_cpi_cleaned.pipe(demean_pct, 252*5, 252)
sig = mag.pipe(omit_leading_na,"any").pipe(high_minus_low) * -1

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings,
                    settings_inject={"use_cov":False})
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : -0.01920601435387334
# Vol       : 0.10377596456399231
# SR        : -0.18507189438870658
# Max DD    : -74.95
#
# C Returns : -0.02428279556169983
# C SR      : -0.2858483141037648
# C Max DD  : -56.02
#
# Hit rate  : 0.486
# W | N | L : 0.49 | 0.0 | 0.51
# W/L Ratio : 0.95

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return    -0.357251    0.150607   -0.246795     2.42951
# sharpe                -0.07448    0.040797   -0.070538    0.485548
# dollar_sharpe         -0.10253    0.022418   -0.076844    0.460774
# trade_sharpe         -0.400655   -0.286707   -0.155275    0.535974
# long_sharpe          -0.430141   -0.516881   -1.287881    0.668599
# short_sharpe          -0.20268   -0.061522     0.13963    0.472764
# sortino                -0.0475    0.019089   -0.028581    0.310559
# max_drawdown        -24.958522  -16.405505  -17.354303  -22.502025
# max_drawdown_start  2003-09-02  2005-08-26  2003-03-21  2004-12-20
# max_drawdown_end    2011-07-27  2007-11-06  2010-06-07  2010-05-18
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return    -2.495906   -1.518337    0.935411   -0.899436     0.20177
# sharpe               -0.435609   -0.328665    0.368528   -0.281972    0.052573
# dollar_sharpe        -0.411485   -0.413007    0.341066   -0.322281    0.036488
# trade_sharpe         -0.637236    -0.67072    0.470161   -1.121815   -0.084371
# long_sharpe          -0.471745   -0.786468   -1.105899   -2.308593   -0.208324
# short_sharpe         -0.674614     1.27718    0.743214   -0.124536    0.182524
# sortino              -0.289801   -0.191249    0.117931   -0.101885    0.025164
# max_drawdown        -65.530764  -43.078016   -6.090718  -27.022896  -25.747296
# max_drawdown_start  2004-12-03  2002-02-27  2009-11-16  2001-07-05  2009-04-20
# max_drawdown_end    2015-06-05  2005-03-18  2013-10-03  2004-03-02  2011-08-09

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Other Freq

# %%
bts = [Backtest(signal = sig, 
               asset_returns = total_returns, 
               tcost = abs(total_returns*0), 
               settings = settings,
               settings_inject = {"rebalance_period":t}) for t in ["monday","tuesday", "wednesday",
                                                                   "thursday", "friday", "monthly"]]
for bt in bts:
  bt.run()
  
gen_plot_rtn(pd.concat([x.model_rtn.rename(x.rebalance_period) for x in [daily_bt]+bts], axis=1))
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/jpm_cpi_xs_g10_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/jpm_cpi_xs_g10_daily.p", "rb"))

# pickle.dump(bts[-1], open("../BT/jpm_cpi_xs_g10_monthly.p", "wb"))
# monthly_bt = pickle.load(open("../BT/jpm_cpi_xs_g10_monthly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %%
# sig = -1 * sig.pipe(omit_leading_na,"any").pipe(high_minus_low) 


# sig = asia_reer_cpi_cleaned.ffill().pct_change().pipe(zscore, 252*5, 252*3).apply(hold_until_flip) * -1
# sig = sig.pipe(demean_xs).pipe(top_bottom_xs)
# sig[abs(sig) < 0.25] = 0
# sig = CAP(sig, 2.5)
