# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2011-07-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %% [markdown]
# # Data integrity

# %% [markdown]
# # Signal

# %%
sig = spot_price_usd[universe].pipe(fill_date, True).rolling(window = 252*6, min_periods = 252*3).apply(lambda x: (x[-1]/x[0])-1).pipe(demean_xs).pipe(top_bottom_xs).pipe(cap_helper, 0.2).pipe(rolling_mean, 5) * -1

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.13238098492717437
# Vol       : 0.11132905153287793
# SR        : 1.1890964946205378
# Max DD    : -11.18
#
# C Returns : 0.13446106616367004
# C SR      : 1.1477512435425605
# C Max DD  : -10.7
#
# Hit rate  : 0.542
# W | N | L : 0.54 | 0.0 | 0.46
# W/L Ratio : 1.18

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return     0.823855    2.843765    1.559578    3.207077
# sharpe                0.112887    1.345641    0.547953    0.491482
# dollar_sharpe         0.079418    1.376862    0.539537    0.471032
# trade_sharpe           0.13345    3.244637    0.832764    0.615298
# long_sharpe            0.13345    3.244637    0.832764     0.82262
# short_sharpe               NaN         NaN         NaN    0.276597
# sortino               0.069225    0.496416    0.209084     0.27403
# max_drawdown        -14.945606   -1.461303   -4.070125  -11.405405
# max_drawdown_start  2012-06-01  2013-05-03  2013-07-05  2012-05-01
# max_drawdown_end    2012-10-17  2013-05-08  2013-10-04  2012-05-30
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     0.753468    3.402703    2.194013    1.530397   17.800399
# sharpe                0.305844    0.371695    0.343979    1.296546    2.733983
# dollar_sharpe         0.287837     0.32033    0.307091    1.261093    1.769241
# trade_sharpe          0.600362    0.368367    0.343979    7.012361    2.733983
# long_sharpe           0.600362         NaN         NaN    7.012361    2.733983
# short_sharpe               NaN    0.368367    0.343979         NaN         NaN
# sortino               0.136379    0.276342     0.24414    0.322382    1.617142
# max_drawdown         -4.017556  -22.895486   -9.585294   -0.519769   -1.196669
# max_drawdown_start  2015-09-07  2013-04-30  2014-05-16  2013-06-12  2016-12-16
# max_drawdown_end    2015-10-09  2013-09-03  2015-09-28  2013-06-13  2016-12-21

# %%
daily_bt.model_rtn.skew()
# Out:
# 0.10871117574811039

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.13960064020322732
# Vol       : 0.11158550513784148
# SR        : 1.2510642850142477
# Max DD    : -11.12
#
# C Returns : 0.14264362566480598
# C SR      : 1.189887944549331
# C Max DD  : -10.65
#
# Hit rate  : 0.548
# W | N | L : 0.55 | 0.0 | 0.45
# W/L Ratio : 1.21

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return     0.872564    2.103043     1.87877    4.039888
# sharpe                0.119204    1.061874    0.672305    0.612141
# dollar_sharpe         0.085459    1.045993    0.666992    0.586504
# trade_sharpe          0.131317     2.71627    1.096174    0.651393
# long_sharpe           0.131317     2.71627    1.096174    0.898071
# short_sharpe               NaN         NaN         NaN    0.243743
# sortino                0.07373     0.26219    0.265524    0.339681
# max_drawdown          -14.4689   -2.194018   -3.515763  -11.372157
# max_drawdown_start  2012-06-01  2013-05-03  2013-07-05  2012-05-01
# max_drawdown_end    2012-12-18  2013-05-08  2013-10-04  2012-05-30
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     0.365433    3.324459    2.450068    1.455994    7.822758
# sharpe                0.147126    0.366173    0.382139    1.222784      1.1457
# dollar_sharpe         0.129887    0.310313    0.338141    1.130214    1.742737
# trade_sharpe          0.224009    0.326829    0.382139     7.04017      1.1457
# long_sharpe           0.224009         NaN         NaN     7.04017      1.1457
# short_sharpe               NaN    0.326829    0.382139         NaN         NaN
# sortino               0.066735    0.266055    0.272975    0.320362    0.673882
# max_drawdown         -4.036504  -22.770569   -9.290114   -0.557221   -1.186326
# max_drawdown_start  2015-09-07  2013-04-30  2014-05-16  2013-06-12  2016-12-16
# max_drawdown_end    2015-10-09  2013-09-03  2015-09-28  2013-06-13  2016-12-21

# %%
plot_bt(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
pickle.dump(daily_bt, open("../BT/value_sgneer_asia_daily.p", "wb"))
daily_bt = pickle.load(open("../BT/value_sgneer_asia_daily.p", "rb"))

pickle.dump(weekly_bt, open("../BT/value_sgneer_asia_weekly.p", "wb"))
weekly_bt = pickle.load(open("../BT/value_sgneer_asia_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis

# %%
# pf.plot_monthly_returns_dist(bt_obj.model_rtn)
