# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = G10_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %%
fwd = ['EUR1M CMPN Curncy', 'GBP1M CMPN Curncy', 'AUD1M CMPN Curncy', 
       'NZD1M CMPN Curncy', 'JPY1M CMPN Curncy', 'CAD1M CMPN Curncy', 
       'SEK1M CMPN Curncy', 'NOK1M CMPN Curncy', 'CHF1M CMPN Curncy']

fwd_scale_g10 = {"EURUSD": 10000,
             "GBPUSD" : 10000,
             "AUDUSD" : 10000,
             "NZDUSD" : 10000,
             "USDJPY" : 100,
             "USDCAD" : 10000,
             "USDSEK" : 10000,
             "USDNOK" : 10000,
             "USDCHF" : 10000}

fwd_data = new_raw_data[fwd]
fwd_data.columns = fwd_scale_g10.keys()
for c in fwd_scale_g10.keys():
  fwd_data[c] = fwd_data[c]/fwd_scale_g10[c]
  
fwd_price_ori = spot_price_ori[fwd_scale_g10.keys()] + fwd_data
# Out:
# C:\Users\vin_s\AppData\Local\Temp/ipykernel_111820/539763738.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fwd_data[c] = fwd_data[c]/fwd_scale_g10[c]

# %%
bp_usd = fwd_price_ori.pipe(standardize_series, "prices") - spot_price_ori[fwd_scale_g10.keys()].pipe(standardize_series, "prices")

# %% [markdown]
# # Data integrity

# %%
spot_price_ori[fwd_scale_g10.keys()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5635 entries, 2000-01-03 to 2021-08-06
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  5635 non-null   float64
#  1   GBPUSD  5635 non-null   float64
#  2   AUDUSD  5635 non-null   float64
#  3   NZDUSD  5635 non-null   float64
#  4   USDJPY  5635 non-null   float64
#  5   USDCAD  5635 non-null   float64
#  6   USDSEK  5635 non-null   float64
#  7   USDNOK  5635 non-null   float64
#  8   USDCHF  5635 non-null   float64
# dtypes: float64(9)
# memory usage: 569.3 KB

# %%
fwd_price_ori.pipe(fill_date).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5635 entries, 2000-01-03 to 2021-08-06
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  5635 non-null   float64
#  1   GBPUSD  5635 non-null   float64
#  2   AUDUSD  5635 non-null   float64
#  3   NZDUSD  5625 non-null   float64
#  4   USDJPY  5635 non-null   float64
#  5   USDCAD  5629 non-null   float64
#  6   USDSEK  5632 non-null   float64
#  7   USDNOK  5629 non-null   float64
#  8   USDCHF  5631 non-null   float64
# dtypes: float64(9)
# memory usage: 440.2 KB

# %% [markdown]
# # Signal

# %%
def custom_skew(series, window):
  num = (series - series.rolling(window).mean())**3
  denom = series.rolling(window).std(ddof=0)**3
  return (num/denom).rolling(window).mean()

# %%
sig = bp_usd.ffill().pipe(custom_skew, 21*3).pipe(cap_helper, 10).pipe(rolling_mean, 5) * -1

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.05170863795355183
# Vol       : 0.11519089277615646
# SR        : 0.4488951922096317
# Max DD    : -34.06
#
# C Returns : 0.04602102037340089
# C SR      : 0.39557418021707946
# C Max DD  : -29.86
#
# Hit rate  : 0.513
# W | N | L : 0.46 | 0.1 | 0.44
# W/L Ratio : 1.06

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return     0.120501    0.571098    1.391644    0.947507
# sharpe                0.075323    0.296052    0.523357    0.380831
# dollar_sharpe         0.065578    0.281952    0.529834    0.368138
# trade_sharpe          0.075323    0.296052    0.523357    0.380831
# long_sharpe          -0.525833    0.124492     0.57323    0.398463
# short_sharpe          0.524754    0.496463    0.545626    0.418783
# sortino               0.043371    0.164719    0.320712    0.223332
# max_drawdown         -5.700077   -5.006373    -7.26624   -8.222095
# max_drawdown_start  2008-10-27  2012-11-14  2010-06-07  2009-11-16
# max_drawdown_end    2016-11-08  2016-08-18  2013-02-01  2013-01-02
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return      1.07333    -0.05541    0.875399   -0.079921   -0.094285
# sharpe                 0.38894   -0.033687    0.362741   -0.040576    -0.01979
# dollar_sharpe         0.394978    -0.04143    0.362813   -0.050499   -0.041601
# trade_sharpe           0.38894   -0.033687    0.362741   -0.040576    -0.01979
# long_sharpe           0.559289   -0.757463     0.31386   -0.179477   -0.148184
# short_sharpe          0.012357    0.418471    0.620977    0.194604    0.486182
# sortino               0.239036    -0.01867    0.204031   -0.022696   -0.007427
# max_drawdown         -9.276535   -7.267691   -7.940848  -10.208685  -16.207343
# max_drawdown_start  2001-09-20  2014-07-09  2004-06-16  2004-02-25  2015-01-13
# max_drawdown_end    2011-10-28  2016-09-07  2004-12-28  2004-12-30  2015-01-15

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.059661878946820804
# Vol       : 0.12195490521098598
# SR        : 0.489212622022901
# Max DD    : -33.41
#
# C Returns : 0.053522419032447456
# C SR      : 0.42042669150239004
# C Max DD  : -29.12
#
# Hit rate  : 0.512
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDEUR      USDGBP  \
# annualized_return     0.188738    0.471799     1.58178    0.961705
# sharpe                0.112452     0.22921     0.56808    0.369908
# dollar_sharpe         0.100708    0.214037    0.568974    0.355622
# trade_sharpe          0.112452     0.22921     0.56808    0.369908
# long_sharpe          -0.474736    -0.13949    0.620837    0.326101
# short_sharpe          0.562444    0.597405     0.55273    0.455635
# sortino                0.06862    0.132624    0.363005    0.227176
# max_drawdown         -5.923244   -6.930015   -8.239673   -8.681803
# max_drawdown_start  2008-10-27  2004-05-17  2010-06-07  2009-11-16
# max_drawdown_end    2016-11-08  2006-04-03  2013-02-01  2013-01-02
#
#                         USDJPY      USDNZD      USDSEK      USDNOK      USDCHF
# annualized_return     1.323494   -0.102067    1.083658   -0.002572   -0.051542
# sharpe                0.461332   -0.058554    0.424079   -0.001176   -0.010478
# dollar_sharpe         0.464457   -0.066163    0.423388   -0.012034   -0.034107
# trade_sharpe          0.461332   -0.058554    0.424079   -0.001176   -0.010478
# long_sharpe           0.612263   -0.848922    0.371085   -0.098726   -0.153619
# short_sharpe          0.167118    0.441574    0.691142     0.19072    0.541365
# sortino               0.295785   -0.034211    0.251318   -0.000687   -0.004122
# max_drawdown         -8.642938    -7.62272   -7.246403   -8.687885   -16.27559
# max_drawdown_start  2008-03-17  2014-07-09  2004-04-21  2003-08-26  2015-01-13
# max_drawdown_end    2011-10-28  2016-09-07  2004-12-03  2004-12-03  2015-01-15

# %%
plot_bt(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/carry_unwinding_g10_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/carry_unwinding_g10_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/carry_unwinding_g10_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/carry_unwinding_g10_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis

# %%
# pf.plot_monthly_returns_dist(bt_obj.model_rtn)
