# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %%
fwd = ['CNH1M CMPN Curncy', 'SGD1M CMPN Curncy', 'THB1M CMPN Curncy', 
       'IHN1M CMPN Curncy', 'IRN1M CMPN Curncy', 'MRN1M CMPN Curncy', 
       'NTN1M CMPN Curncy', 'KWN1M CMPN Curncy', 'PPN1M CMPN Curncy']

fwd_scale_asia = {'USDCNH': 10000,
                  'USDSGD': 10000,
                  'USDTHB': 100,
                  'USDIDR': 1,
                  'USDINR': 100,
                  'USDMYR': 10000,
                  'USDTWD': 1,
                  'USDKRW': 1,
                  'USDPHP': 1}

fwd_data = new_raw_data[fwd].pipe(fill_date)
fwd_data.columns = fwd_scale_asia.keys()
for c in fwd_scale_asia.keys():
  fwd_data[c] = fwd_data[c]/fwd_scale_asia[c]
  
fwd_price_ori = spot_price_ori[fwd_scale_asia.keys()] + fwd_data

# %%
rx = fwd_price_ori.pipe(standardize_series, "prices").pipe(np.log10).shift(1) - \
     spot_price_ori[fwd_scale_asia.keys()].pipe(standardize_series, "prices").pipe(np.log10)

# %% [markdown]
# # Data integrity

# %%
rx.pipe(fill_date).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5635 entries, 2000-01-03 to 2021-08-06
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   USDCNH  2841 non-null   float64
#  1   USDSGD  5624 non-null   float64
#  2   USDTHB  5612 non-null   float64
#  3   USDIDR  3677 non-null   float64
#  4   USDINR  4005 non-null   float64
#  5   USDMYR  4056 non-null   float64
#  6   USDTWD  5596 non-null   float64
#  7   USDKRW  4064 non-null   float64
#  8   USDPHP  4030 non-null   float64
# dtypes: float64(9)
# memory usage: 440.2 KB

# %%
msmx(rx.pipe(fill_date))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
rx = rx.pipe(fill_date, True)

# %%
def rsv(x):
  mean = x.mean()
  rvu = sum([x**2 for x in x if x > mean])
  rvd = sum([x**2 for x in x if x <= mean])
  return rvd - rvu

# %%
rsv_signal = rx.groupby(rx.index.strftime('%Y-%m')).agg([rsv])
rsv_signal.columns = [x[0] for x in rsv_signal.columns]
rsv_signal.index = rx.loc[rx.groupby(rx.index.to_period('M')).apply(lambda x: x.index.max())].index

# %%
sig = rsv_signal.pipe(high_minus_low).pipe(fill_date, True)

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.06212669974017966
# Vol       : 0.10255064782490045
# SR        : 0.6058147954975142
# Max DD    : -25.39
#
# C Returns : 0.05850057493835422
# C SR      : 0.5860422052176236
# C Max DD  : -23.91
#
# Hit rate  : 0.526
# W | N | L : 0.53 | 0.0 | 0.47
# W/L Ratio : 1.11

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return    -1.637397    4.991107    0.672564   -0.034217
# sharpe               -0.367747    1.142581     0.11299    -0.00992
# dollar_sharpe        -0.432214    1.010359    0.093796   -0.027657
# trade_sharpe         -0.434318    1.884628    0.123301     0.03544
# long_sharpe          -0.263521    2.117575    0.130945    0.434633
# short_sharpe         -1.539865    1.851519   -0.009549   -0.866348
# sortino              -0.193323    0.450337    0.068642   -0.003804
# max_drawdown        -45.126109   -8.266085  -22.454978  -11.112535
# max_drawdown_start  2001-07-13  2013-04-19  2002-04-29  2008-10-08
# max_drawdown_end    2008-07-15  2016-04-19  2005-03-29  2016-11-08
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return    -0.174233    2.002491    1.226196   -0.455544    0.521782
# sharpe               -0.045347    0.400884    0.226491   -0.135905    0.249827
# dollar_sharpe        -0.068233    0.368669    0.201522   -0.160181    0.273696
# trade_sharpe         -0.021105    0.480374     0.22233   -0.227207    0.763711
# long_sharpe          -0.346773    -1.22161         NaN   -0.111573    0.431308
# short_sharpe          0.287123    0.538842     0.22233   -0.660049    5.750961
# sortino              -0.019096    0.238417    0.097988    -0.05244    0.068859
# max_drawdown        -16.670871  -16.023839   -11.79307  -13.839665   -3.248747
# max_drawdown_start  2001-07-18  2011-09-02  2011-06-07  2015-05-15  2001-06-15
# max_drawdown_end    2005-03-16  2013-09-03  2015-09-28  2016-04-07  2011-11-16

# %%
plot_bt(daily_bt)

# %%
# pickle.dump(daily_bt, open("../BT/rx_skew_asia.p", "wb"))
# daily_bt = pickle.load(open("../BT/rx_skew_asia.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis

# %%
# pf.plot_monthly_returns_dist(bt_obj.model_rtn)
