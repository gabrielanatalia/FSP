# %% [markdown]
# use the spread 2Y and spread 5Y of swaps and take zscore of 1Y
# then take average between the 2 signals

# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
# Asia FX
universe = ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %%
swaps = pd.read_csv("../../Dymon/Code Data/swaps.csv", index_col=0).iloc[2:]

# %%
swaps.columns = ["2Y", "5Y"]
swaps = swaps.astype(float)
swaps.index = pd.to_datetime(swaps.index)

# %%
spread_2y = swaps["2Y"]
spread_5y = swaps["5Y"]
spread_2y.index.name = "date"
spread_5y.index.name = "date"

# %% [markdown]
# # Data integrity

# %%
pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5645 entries, 2000-01-03 to 2021-08-20
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2Y      5644 non-null   float64
#  1   5Y      5644 non-null   float64
# dtypes: float64(2)
# memory usage: 132.3 KB

# %%
msmx(pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
## 1Y zscore of 5Y swap spread, capped at 2
signal_5y = spread_5y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)

## 1Y zscore of 2Y swap spread, capped at 2
signal_2y = spread_2y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)

## Equal weighted average
signal = (signal_5y + signal_2y)/2

## Slow down using 5-day simple moving average
signal = signal.pipe(rolling_mean, 5)

sig = pd.concat([signal] * len(total_returns.columns), axis=1)
sig.columns = total_returns.columns
sig.index = pd.to_datetime(sig.index)

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig.drop("USDCNH",1), asset_returns = total_returns.drop("USDCNH",1), tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
get_summary(daily_bt)
plot_bt(daily_bt)
# Out:
# C:\Users\vin_s\AppData\Local\Temp/ipykernel_62276/1781514676.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   daily_bt = Backtest(signal = sig.drop("USDCNH",1), asset_returns = total_returns.drop("USDCNH",1), tcost = abs(total_returns*0), settings = settings)
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Returns   : 0.08071908293868342
# Vol       : 0.11081577150064469
# SR        : 0.7284078957859697
# Max DD    : -31.17
#
# C Returns : 0.07742413228813305
# C SR      : 0.7185300339088544
# C Max DD  : -27.49
#
# Hit rate  : 0.511
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.0807640942968079
# Vol       : 0.11091953101956309
# SR        : 0.7281323095619958
# Max DD    : -31.17
#
# C Returns : 0.07745735983143633
# C SR      : 0.7178749862385441
# C Max DD  : -27.49
#
# Hit rate  : 0.514
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.06

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return     0.662718    1.887563    0.901226    0.058273
# sharpe                0.325814    0.879903    0.421074    0.028837
# dollar_sharpe         0.329121    0.890168    0.422527    0.019094
# trade_sharpe          0.325814    0.879903    0.421074    0.028837
# long_sharpe           -0.05284   -0.024603    0.586971   -0.414672
# short_sharpe          0.583401     1.40727    0.317654    0.300646
# sortino               0.201105    0.521323    0.271438    0.017251
# max_drawdown         -8.199167   -8.373926   -8.630192  -13.221948
# max_drawdown_start  2001-09-14  2002-07-16  2002-07-17  2004-05-10
# max_drawdown_end    2007-07-24  2004-03-25  2004-03-12  2011-09-22
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     0.481213    1.872391    0.861534    1.342639      1.1846
# sharpe                0.248992    0.908366    0.401452    0.693342    0.632262
# dollar_sharpe         0.249341    0.837255    0.397348    0.704358    0.612327
# trade_sharpe          0.248992    0.908366    0.401452    0.693342    0.632262
# long_sharpe          -0.481436    0.489724    0.128717    0.408808   -0.206425
# short_sharpe          0.844352    1.226678    0.670353    0.898063    1.514958
# sortino               0.152577    0.595006    0.246893    0.451567    0.381092
# max_drawdown        -12.797899   -6.290636   -5.284851   -5.480868   -5.680728
# max_drawdown_start  2002-07-22  2010-11-05  2005-08-29  2005-12-30  2013-05-31
# max_drawdown_end    2007-07-23  2011-12-14  2006-05-08  2006-05-10  2015-07-02

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.08029268626984652
# Vol       : 0.11178102234232128
# SR        : 0.7183033809080399
# Max DD    : -29.35
#
# C Returns : 0.07684319944296704
# C SR      : 0.6782356430811403
# C Max DD  : -26.04
#
# Hit rate  : 0.511
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.04

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return     0.729224    1.889801    0.916945    0.077517
# sharpe                0.358247    0.862312    0.425853    0.038012
# dollar_sharpe          0.36181    0.870456    0.425795    0.028078
# trade_sharpe          0.358247    0.862312    0.425853    0.038012
# long_sharpe          -0.001054   -0.018651    0.579328    -0.35291
# short_sharpe          0.601615    1.361798    0.331398     0.27945
# sortino               0.221291    0.500413    0.272239    0.022902
# max_drawdown         -6.788104     -8.1265   -8.001709  -12.923491
# max_drawdown_start  2001-09-14  2002-07-16  2002-07-17  2004-05-10
# max_drawdown_end    2007-07-24  2004-03-29  2004-02-12  2010-05-26
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     0.480127    1.855788    0.889221    1.223059     0.97441
# sharpe                0.246768     0.89071    0.408461    0.630897    0.526409
# dollar_sharpe         0.245966    0.816293    0.398367     0.62922     0.50379
# trade_sharpe          0.246768     0.89071    0.408461    0.630897    0.526409
# long_sharpe          -0.465382    0.398331    0.093023    0.365757    -0.41955
# short_sharpe          0.833588    1.265368    0.705189    0.823799    1.460367
# sortino                0.15302    0.584237    0.252127    0.409241    0.305181
# max_drawdown         -11.97313   -5.971892   -5.555329   -5.535014   -5.700915
# max_drawdown_start  2002-07-10  2010-11-05  2005-08-29  2005-12-30  2013-05-08
# max_drawdown_end    2007-07-23  2011-12-14  2006-05-08  2006-05-10  2015-08-10

# %%
plot_bt(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/carry_unwinding_asia_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/carry_unwinding_asia_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/carry_unwinding_asia_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/carry_unwinding_asia_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis
