# %% [markdown]
# use the spread 2Y and spread 5Y of swaps and take zscore of 1Y
# then take average between the 2 signals

# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\DW\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
universe = G10_FX + ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %%
swaps = pd.read_csv("../../Dymon/Code Data/swaps.csv", index_col=0).iloc[2:]

# %%
swaps.columns = ["2Y", "5Y"]
swaps = swaps.astype(float)
swaps.index = pd.to_datetime(swaps.index)

# %%
spread_2y = swaps["2Y"]
spread_5y = swaps["5Y"]
spread_2y.index.name = "date"
spread_5y.index.name = "date"

# %% [markdown]
# # Data integrity

# %%
pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5645 entries, 2000-01-03 to 2021-08-20
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2Y      5644 non-null   float64
#  1   5Y      5644 non-null   float64
# dtypes: float64(2)
# memory usage: 132.3 KB

# %%
msmx(pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
## 1Y zscore of 5Y swap spread, capped at 2
signal_5y = spread_5y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)

## 1Y zscore of 2Y swap spread, capped at 2
signal_2y = spread_2y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)

## Equal weighted average
signal = (signal_5y + signal_2y)/2

## Slow down using 5-day simple moving average
signal = signal.pipe(rolling_mean, 5)

sig = pd.concat([signal] * len(total_returns.columns), axis=1)
sig.columns = total_returns.columns
sig.index = pd.to_datetime(sig.index)

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings, 
                    asset_groups={"ASIA":ASIA_FX, "G10":G10_FX})
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.06758461522088309
# Vol       : 0.10856421556945192
# SR        : 0.6225312352360443
# Max DD    : -25.47
#
# C Returns : 0.06363215801919779
# C SR      : 0.6080084430091167
# C Max DD  : -22.68
#
# Hit rate  : 0.511
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDCHF      USDCNH  \
# annualized_return     0.430271    0.294333    0.231816    0.742753
# sharpe                0.459231    0.308529    0.251386    0.742402
# dollar_sharpe         0.461264    0.308724     0.24714    0.721197
# trade_sharpe          0.459231    0.308529    0.251386    0.742402
# long_sharpe           0.011992    0.018337    0.097914    0.135679
# short_sharpe          0.785344    0.507094    0.358973    1.677499
# sortino               0.289394    0.194119    0.157284    0.529126
# max_drawdown         -2.045704   -2.506766   -2.891206   -2.779503
# max_drawdown_start  2003-07-03  2002-07-09  2011-08-09  2013-05-31
# max_drawdown_end    2004-03-12  2007-03-05  2014-06-30  2015-07-02
#
#                         USDEUR      USDGBP      USDIDR      USDINR  \
# annualized_return     0.279508   -0.004267    0.400259     1.11095
# sharpe                0.313487   -0.004736    0.287436    0.961798
# dollar_sharpe         0.309853   -0.009266    0.286685    0.923666
# trade_sharpe          0.313487   -0.004736    0.287436    0.961798
# long_sharpe           0.144726   -0.415273    0.105509    0.462061
# short_sharpe          0.438307    0.263269    0.433894    1.338419
# sortino               0.202583   -0.003013    0.164025    0.673115
# max_drawdown         -2.713579   -6.028499   -3.011313   -3.338053
# max_drawdown_start  2009-11-25  2003-06-17  2008-10-10  2011-08-01
# max_drawdown_end    2012-07-24  2014-07-02  2008-10-27  2012-06-22
#
#                         USDJPY      USDKRW      USDMYR      USDNOK  \
# annualized_return      0.20159    0.198455    0.784095    0.339208
# sharpe                0.231476    0.175973    0.687446     0.37448
# dollar_sharpe         0.226963    0.171159    0.691747    0.372938
# trade_sharpe          0.231476    0.175973    0.687446     0.37448
# long_sharpe           0.344615   -0.442978    0.414789    0.116339
# short_sharpe          0.150696    0.596915      0.9033    0.563502
# sortino               0.148492    0.114746    0.437378     0.23048
# max_drawdown         -2.766779   -5.820645   -2.709733   -2.986501
# max_drawdown_start  2011-09-22  2004-05-10  2005-11-11  2002-07-16
# max_drawdown_end    2014-07-17  2011-09-22  2006-05-10  2007-07-16
#
#                         USDNZD      USDPHP      USDSEK      USDSGD  \
# annualized_return     0.273405    0.237219    0.194807    0.470741
# sharpe                0.293349    0.217207    0.220618    0.426291
# dollar_sharpe         0.292038    0.217955     0.21672    0.425145
# trade_sharpe          0.293349    0.217207    0.220618    0.426291
# long_sharpe          -0.235613   -0.517867    0.044064    -0.13329
# short_sharpe          0.681171    0.862127    0.345895    0.835704
# sortino                0.18503     0.12989    0.135129     0.27331
# max_drawdown         -2.637937   -6.968518   -2.327437   -3.606532
# max_drawdown_start  2003-09-02  2002-07-22  2003-06-13  2002-07-19
# max_drawdown_end    2005-12-05  2006-04-04  2007-07-20  2004-03-12
#
#                         USDTHB      USDTWD
# annualized_return     0.840635    0.415567
# sharpe                 0.71163    0.333771
# dollar_sharpe         0.713518    0.328619
# trade_sharpe           0.71163    0.333771
# long_sharpe          -0.126847    0.294788
# short_sharpe          1.251468    0.362464
# sortino               0.417107    0.230418
# max_drawdown         -5.635448   -5.242274
# max_drawdown_start  2002-07-16  2002-07-17
# max_drawdown_end    2004-03-25  2004-03-12

# %%
plot_bt2(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"},
             asset_groups={"ASIA":ASIA_FX, "G10":G10_FX})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.07035970922866874
# Vol       : 0.1115989856496762
# SR        : 0.6304690747775886
# Max DD    : -20.82
#
# C Returns : 0.06622289891422468
# C SR      : 0.6116397836918517
# C Max DD  : -19.41
#
# Hit rate  : 0.512
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDCHF      USDCNH  \
# annualized_return     0.495045    0.330706    0.216799    0.576308
# sharpe                0.519758    0.341937    0.229601    0.592544
# dollar_sharpe         0.522006    0.342972    0.224717      0.5674
# trade_sharpe          0.519758    0.341937    0.229601    0.592544
# long_sharpe           0.114222    0.077326    0.101795   -0.074562
# short_sharpe          0.826954    0.530017    0.320851     1.48719
# sortino               0.329375    0.213984    0.139322    0.385379
# max_drawdown         -1.694499   -2.655062   -3.025914   -2.843717
# max_drawdown_start  2002-06-21  2002-07-09  2011-08-09  2013-05-31
# max_drawdown_end    2002-08-05  2007-03-05  2014-06-30  2015-08-10
#
#                         USDEUR      USDGBP      USDIDR      USDINR  \
# annualized_return     0.327425     0.09216    0.508686    1.156515
# sharpe                0.360461    0.098601    0.345917     0.96556
# dollar_sharpe         0.356996    0.094093    0.343309    0.924546
# trade_sharpe          0.360461    0.098601    0.345917     0.96556
# long_sharpe           0.180788   -0.318962    0.068695    0.384357
# short_sharpe          0.497139    0.374308    0.542158    1.402878
# sortino               0.230842    0.061571    0.208908    0.684745
# max_drawdown         -2.767733   -5.050989   -2.598231   -3.232519
# max_drawdown_start  2009-11-25  2003-06-17  2005-08-29  2011-08-01
# max_drawdown_end    2012-07-24  2014-07-02  2007-03-05  2012-06-22
#
#                         USDJPY      USDKRW      USDMYR      USDNOK  \
# annualized_return     0.230852     0.17158    0.689448    0.316556
# sharpe                0.262537    0.149768    0.606211    0.348151
# dollar_sharpe         0.258236    0.143846    0.602654    0.347196
# trade_sharpe          0.262537    0.149768    0.606211    0.348151
# long_sharpe           0.348575   -0.410557    0.296778    0.150331
# short_sharpe          0.198394     0.54753    0.846933    0.495825
# sortino               0.165457    0.095179    0.378314    0.212372
# max_drawdown         -2.720976   -6.147889   -2.731151   -2.615171
# max_drawdown_start  2012-09-13  2004-05-10  2005-12-30  2002-07-16
# max_drawdown_end    2014-07-17  2011-09-22  2006-05-10  2007-07-16
#
#                         USDNZD      USDPHP      USDSEK      USDSGD  \
# annualized_return      0.33767    0.138529    0.221761    0.516837
# sharpe                0.359875    0.124115    0.248703    0.458062
# dollar_sharpe         0.359432    0.122227    0.245457    0.456538
# trade_sharpe          0.359875    0.124115    0.248703    0.458062
# long_sharpe          -0.049838   -0.523102    0.115238   -0.104429
# short_sharpe           0.67062    0.704428     0.34623    0.867173
# sortino               0.231541    0.073583    0.151768    0.288284
# max_drawdown          -1.94299   -6.473604   -1.849818   -2.868102
# max_drawdown_start  2003-09-02  2002-07-10  2003-06-13  2002-07-19
# max_drawdown_end    2005-03-18  2006-04-04  2007-07-20  2004-02-11
#
#                         USDTHB      USDTWD
# annualized_return     0.782996    0.441786
# sharpe                0.625609    0.351857
# dollar_sharpe          0.63115    0.347379
# trade_sharpe          0.625609    0.351857
# long_sharpe          -0.112055    0.268807
# short_sharpe          1.082244    0.411519
# sortino               0.343572     0.23701
# max_drawdown         -5.718834   -4.967911
# max_drawdown_start  2002-07-16  2002-07-17
# max_drawdown_end    2004-03-29  2004-02-12

# %%
plot_bt2(weekly_bt)

# %%
daily_bt.model_rtn.skew()
# Out:
# 0.2189095866540894

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
bts = [Backtest(signal = sig,
             asset_returns = total_returns,
             tcost = abs(total_returns*0),
             settings = settings,
             settings_inject = {"rebalance_period":t}) for t in ["monday","tuesday", "wednesday",
                                                                 "thursday", "friday"]]
for bt in bts:
  bt.run()
  
gen_plot_rtn(pd.concat([x.model_rtn.rename(x.rebalance_period) for x in [daily_bt]+bts], axis=1))
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/carry_unwinding_all_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/carry_unwinding_all_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/carry_unwinding_all_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/carry_unwinding_all_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# ### 1. GFC regime

# %%
full_regime_plot(weekly_bt, gfc_regime)

# %% [markdown]
# ### 2. Rates regime

# %%
full_regime_plot(weekly_bt, rates_regime)

# %% [markdown]
# ### 3. Volatility cycle

# %%
full_regime_plot(weekly_bt, vol_regime)

# %% [markdown]
# ### 4. Economic cycle

# %%
full_regime_plot(weekly_bt, cycle_regime)

# %% [markdown]
# ### 5. Macroeconomic framework

# %%
full_regime_plot(weekly_bt, macro_regime)

# %% [markdown]
# # Sensitivity Analysis

# %%
def signal_generation(lookback):
    signal_5y = spread_5y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, lookback, typ="median").pipe(cap_helper, 2)
    signal_2y = spread_2y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, lookback, typ="median").pipe(cap_helper, 2)
    signal = (signal_5y + signal_2y)/2
    signal = signal.pipe(rolling_mean, 5)
    sig = pd.concat([signal] * len(total_returns.columns), axis=1)
    sig.columns = total_returns.columns
    sig.index = pd.to_datetime(sig.index)
    return sig

# %%
signalsa = [signal_generation(i) for i in [int(252/12),int(252/4),int(252/2),252,252*2,252*3,252*4,252*5]] 
# signalsa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-316f039b0e10> in <module>
# ----> 1 signalsa = [signal_generation(i) for i in [int(252/4),int(252/2),252,252*2,252*3,252*4,252*5]]
#       2 # signalsa
#
# <ipython-input-1-316f039b0e10> in <listcomp>(.0)
# ----> 1 signalsa = [signal_generation(i) for i in [int(252/4),int(252/2),252,252*2,252*3,252*4,252*5]]
#       2 # signalsa
#
# NameError: name 'signal_generation' is not defined

# %%
backtestsa = [Backtest(signal = x, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings, 
                    asset_groups={"ASIA":ASIA_FX, "G10":G10_FX}) for x in signalsa]
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns

# %%
for testsa in backtestsa:
    testsa.run()
backtestsa
# Out:
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]
# [<genesis.Backtest at 0x196398874f0>,
#  <genesis.Backtest at 0x196342930a0>,
#  <genesis.Backtest at 0x1963a23e340>,
#  <genesis.Backtest at 0x1963a23e880>,
#  <genesis.Backtest at 0x196398a0790>,
#  <genesis.Backtest at 0x19633a121f0>,
#  <genesis.Backtest at 0x19633a12f10>]

# %%
sa_variants = pd.DataFrame([x.model_rtn for x  in backtestsa]).T
sa_variants.columns = ["1M lookback", "3M lookback", "6M lookback", "1Y lookback", "2Y lookback","3Y lookback","4Y lookback","5Y lookback"]
gen_plot_rtn(sa_variants)
# Out:
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>
