# %% [markdown]
# use the spread 2Y and spread 5Y of swaps and take zscore of 1Y
# then take average between the 2 signals

# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# regime data in construction

# %%
universe = G10_FX + ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %%
swaps = pd.read_csv("../../Dymon/Code Data/swaps.csv", index_col=0).iloc[2:]

# %%
swaps.columns = ["2Y", "5Y"]
swaps = swaps.astype(float)
swaps.index = pd.to_datetime(swaps.index)

# %%
spread_2y = swaps["2Y"]
spread_5y = swaps["5Y"]
spread_2y.index.name = "date"
spread_5y.index.name = "date"

# %% [markdown]
# # Data integrity

# %%
pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5645 entries, 2000-01-03 to 2021-08-20
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2Y      5644 non-null   float64
#  1   5Y      5644 non-null   float64
# dtypes: float64(2)
# memory usage: 132.3 KB

# %%
msmx(pd.concat([spread_2y.pipe(fill_date), spread_5y.pipe(fill_date)], axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Signal

# %%
signal1 = spread_5y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)
signal2 = spread_2y.pipe(fill_date, True).pipe(omit_trailing_na).pipe(zscore, 252, typ="median").pipe(cap_helper, 2)
signal = (signal1 + signal2)/2
signal = signal.pipe(rolling_mean, 5)
# signal.plot()
sig = pd.concat([signal] * len(total_returns.columns), axis=1)
sig.columns = total_returns.columns
sig.index = pd.to_datetime(sig.index)

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, 
                    asset_returns = total_returns, 
                    tcost = abs(total_returns*0), 
                    settings = settings, 
                    asset_groups={"ASIA":ASIA_FX, "G10":G10_FX})
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.06758461522088302
# Vol       : 0.10856421556945178
# SR        : 0.6225312352360444
# Max DD    : -25.47
#
# C Returns : 0.06363215801919779
# C SR      : 0.6080084430091162
# C Max DD  : -22.68
#
# Hit rate  : 0.511
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDCHF      USDCNH  \
# annualized_return     0.380598    0.260354    0.205054     0.23547
# sharpe                0.431896    0.290172    0.236431    0.417798
# dollar_sharpe         0.433807    0.290355    0.232437    0.417522
# trade_sharpe          0.431896    0.290172    0.236431    0.417798
# long_sharpe           0.011992    0.018337    0.097914    0.135679
# short_sharpe          0.784981    0.506859    0.358807    1.675013
# sortino               0.255985    0.171709    0.139126    0.167746
# max_drawdown         -2.045704   -2.506766   -2.891206   -2.779503
# max_drawdown_start  2003-07-03  2002-07-09  2011-08-09  2013-05-31
# max_drawdown_end    2004-03-12  2007-03-05  2014-06-30  2015-07-02
#
#                         USDEUR      USDGBP      USDIDR      USDINR  \
# annualized_return      0.24724   -0.003775     0.34268    0.982696
# sharpe                0.294835   -0.004454    0.265958      0.9044
# dollar_sharpe         0.291417   -0.008715     0.26287    0.868558
# trade_sharpe          0.294835   -0.004454    0.265958      0.9044
# long_sharpe           0.144726   -0.415273    0.105509    0.462061
# short_sharpe          0.438104    0.263147    0.433683    1.337796
# sortino               0.179196   -0.002665    0.140429    0.595407
# max_drawdown         -2.713579   -6.028499   -3.011313   -3.338053
# max_drawdown_start  2009-11-25  2003-06-17  2008-10-10  2011-08-01
# max_drawdown_end    2012-07-24  2014-07-02  2008-10-27  2012-06-22
#
#                         USDJPY      USDKRW      USDMYR      USDNOK  \
# annualized_return     0.178317    0.175545    0.522435    0.300048
# sharpe                0.217705    0.165506    0.560995    0.352196
# dollar_sharpe         0.213461    0.160978    0.563516    0.350745
# trade_sharpe          0.217705    0.165506    0.560995    0.352196
# long_sharpe           0.344615   -0.442978    0.414451    0.116339
# short_sharpe          0.150626    0.596639      0.9033    0.563241
# sortino               0.131349    0.101499    0.291421    0.203872
# max_drawdown         -2.766779   -5.820645   -2.709733   -2.986501
# max_drawdown_start  2011-09-22  2004-05-10  2005-11-11  2002-07-16
# max_drawdown_end    2014-07-17  2011-09-22  2006-05-10  2007-07-16
#
#                         USDNZD      USDPHP      USDSEK      USDSGD  \
# annualized_return     0.241841    0.209833    0.172317    0.416396
# sharpe                0.275896    0.204286    0.207494    0.400919
# dollar_sharpe         0.274663     0.20499    0.203828    0.399842
# trade_sharpe          0.275896    0.204286    0.207494    0.400919
# long_sharpe          -0.235613   -0.517867    0.044064    -0.13329
# short_sharpe          0.680855    0.861728    0.345735    0.835317
# sortino               0.163669    0.114895    0.119529    0.241757
# max_drawdown         -2.637937   -6.968518   -2.327437   -3.606532
# max_drawdown_start  2003-09-02  2002-07-22  2003-06-13  2002-07-19
# max_drawdown_end    2005-12-05  2006-04-04  2007-07-20  2004-03-12
#
#                         USDTHB      USDTWD
# annualized_return     0.743588    0.367591
# sharpe                0.669226    0.313911
# dollar_sharpe         0.671001    0.309066
# trade_sharpe          0.669226    0.313911
# long_sharpe          -0.126847    0.294788
# short_sharpe          1.250886    0.362296
# sortino               0.368954    0.203818
# max_drawdown         -5.635448   -5.242274
# max_drawdown_start  2002-07-16  2002-07-17
# max_drawdown_end    2004-03-25  2004-03-12

# %%
plot_bt2(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"},
             asset_groups={"ASIA":ASIA_FX, "G10":G10_FX})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Sector scaling ...
#     Grouping by [ASIA, G10]
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.07035970922866835
# Vol       : 0.11159898564967612
# SR        : 0.6304690747775856
# Max DD    : -20.82
#
# C Returns : 0.06622289891422468
# C SR      : 0.6116397836918502
# C Max DD  : -19.41
#
# Hit rate  : 0.512
# W | N | L : 0.51 | 0.0 | 0.49
# W/L Ratio : 1.05

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDAUD      USDCAD      USDCHF      USDCNH  \
# annualized_return     0.423495    0.282908    0.185465    0.182443
# sharpe                0.480704    0.316258    0.212363    0.333316
# dollar_sharpe         0.482783    0.317215    0.207845     0.33258
# trade_sharpe          0.480704    0.316258    0.212363    0.333316
# long_sharpe           0.114222    0.077326    0.101795   -0.074562
# short_sharpe           0.82655    0.529759    0.320694    1.484966
# sortino                0.28177    0.183057    0.119185       0.122
# max_drawdown         -1.694499   -2.655062   -3.025914   -2.843717
# max_drawdown_start  2002-06-21  2002-07-09  2011-08-09  2013-05-31
# max_drawdown_end    2002-08-05  2007-03-05  2014-06-30  2015-08-10
#
#                         USDEUR      USDGBP      USDIDR      USDINR  \
# annualized_return     0.280101     0.07884    0.435164    0.989361
# sharpe                 0.33339    0.091199    0.319939    0.892839
# dollar_sharpe         0.330185     0.08703    0.317527    0.854933
# trade_sharpe           0.33339    0.091199    0.319939    0.892839
# long_sharpe           0.180788   -0.318962    0.068695    0.384357
# short_sharpe          0.496896    0.374125    0.541894     1.40219
# sortino               0.197478    0.052672    0.178714    0.585777
# max_drawdown         -2.767733   -5.050989   -2.598231   -3.232519
# max_drawdown_start  2009-11-25  2003-06-17  2005-08-29  2011-08-01
# max_drawdown_end    2012-07-24  2014-07-02  2007-03-05  2012-06-22
#
#                         USDJPY      USDKRW      USDMYR      USDNOK  \
# annualized_return     0.197486    0.146781    0.459217    0.270803
# sharpe                0.242824    0.138524    0.494653    0.322005
# dollar_sharpe         0.238846    0.133047    0.495506    0.321121
# trade_sharpe          0.242824    0.138524    0.494653    0.322005
# long_sharpe           0.348575   -0.410557    0.296536    0.150331
# short_sharpe          0.198298    0.547264    0.846933    0.495584
# sortino               0.141544    0.081422    0.251982    0.181678
# max_drawdown         -2.720976   -6.147889   -2.731151   -2.615171
# max_drawdown_start  2012-09-13  2004-05-10  2005-12-30  2002-07-16
# max_drawdown_end    2014-07-17  2011-09-22  2006-05-10  2007-07-16
#
#                         USDNZD      USDPHP      USDSEK      USDSGD  \
# annualized_return     0.288866    0.118507    0.189709    0.442137
# sharpe                0.332848    0.114798     0.23003    0.423651
# dollar_sharpe         0.332438    0.113051    0.227027    0.422242
# trade_sharpe          0.332848    0.114798     0.23003    0.423651
# long_sharpe          -0.049838   -0.523102    0.115238   -0.104429
# short_sharpe          0.670293    0.704084    0.346062     0.86675
# sortino               0.198075    0.062948    0.129833    0.246617
# max_drawdown          -1.94299   -6.473604   -1.849818   -2.868102
# max_drawdown_start  2003-09-02  2002-07-10  2003-06-13  2002-07-19
# max_drawdown_end    2005-03-18  2006-04-04  2007-07-20  2004-02-11
#
#                         USDTHB      USDTWD
# annualized_return     0.669828    0.377933
# sharpe                0.578582    0.325433
# dollar_sharpe         0.583705    0.321291
# trade_sharpe          0.578582    0.325433
# long_sharpe          -0.112055    0.268807
# short_sharpe          1.081715    0.411319
# sortino               0.293915    0.202754
# max_drawdown         -5.718834   -4.967911
# max_drawdown_start  2002-07-16  2002-07-17
# max_drawdown_end    2004-03-29  2004-02-12

# %%
plot_bt2(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
bts = [Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":t}) for t in ["monday","tuesday", "wednesday",
                                                                 "thursday", "friday"]]
for bt in bts:
  bt.run()
  
gen_plot_rtn(pd.concat([x.model_rtn.rename(x.rebalance_period) for x in [daily_bt]+bts], axis=1))
# Out:
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]
# <AxesSubplot:xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/carry_unwinding_all_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/carry_unwinding_all_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/carry_unwinding_all_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/carry_unwinding_all_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# ### 1. GFC regime

# %%
full_regime_plot(weekly_bt,regime1)

# %% [markdown]
# ### 2. Bull/bear & steep/flat

# %%
full_regime_plot(weekly_bt,regime2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_51912/1387086901.py in <module>
# ----> 1 full_regime_plot(weekly_bt,regime2)
#
# ~\National University of Singapore\FSP Dymon AY21 22 Term 1 - Documents\Codebase\01_Carry\..\genesis.py in full_regime_plot(bt_obj, regime_data, t)
#    1202
#    1203   regimes = regime_data.unique()
# -> 1204   fig.add_subplot(gs[0:4]).set_label(gen_regime_plot(bt_obj.model_rtn, regime_data))
#    1205
#    1206   for i,r in zip(range(4,8)[:len(regimes)], regimes):
#
# ~\National University of Singapore\FSP Dymon AY21 22 Term 1 - Documents\Codebase\01_Carry\..\genesis.py in gen_regime_plot(model_rtn, regime_data)
#    1165   regime_names = returns_regime["regime"].unique()
#    1166   regime_mapper = {k:v for v,k in enumerate(regime_names)}
# -> 1167   returns_regime["regime_number"] = returns_regime["regime"].apply(lambda x: regime_mapper[x])
#    1168
#    1169   num_classes = len(regime_names)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\National University of Singapore\FSP Dymon AY21 22 Term 1 - Documents\Codebase\01_Carry\..\genesis.py in <lambda>(x)
#    1165   regime_names = returns_regime["regime"].unique()
#    1166   regime_mapper = {k:v for v,k in enumerate(regime_names)}
# -> 1167   returns_regime["regime_number"] = returns_regime["regime"].apply(lambda x: regime_mapper[x])
#    1168
#    1169   num_classes = len(regime_names)
#
# KeyError: nan

# %% [markdown]
# # Sensitivity Analysis
