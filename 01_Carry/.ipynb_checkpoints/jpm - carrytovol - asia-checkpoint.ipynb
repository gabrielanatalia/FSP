# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# regime under construction

# %%
universe = ASIA_FX
total_returns = total_returns_usd[universe]
spot_returns = spot_returns_usd[universe]
carry_returns = carry_returns_usd[universe]

# %% [markdown]
# # Settings

# %%
settings = Settings(start_date = "2000-01-01", end_date = "2016-12-31", notional = 100, implementation_lag = 1,
             asset_scaling_method="simple", asset_scaling_target=0.1, asset_scaling_width=126, rebalance_period="daily",
             sector_scaling_method="simple", sector_scaling_target=0.1, sector_scaling_width=126,
             portfolio_scaling_method="simple", portfolio_scaling_target=0.1, portfolio_scaling_width=252)

# %% [markdown]
# # Other Data

# %% [markdown]
# # Data integrity

# %% [markdown]
# # Signal

# %%
num = carry_returns.pipe(fill_date, True)
denom = spot_returns.pipe(fill_date, True).pipe(rolling_vol, 21*3)
signal = (num/denom).pipe(omit_leading_na, "any").pipe(high_minus_low) * -1
sig = signal * (1/spot_returns.pipe(fill_date, True).pipe(rolling_vol, 21*6))

# %% [markdown]
# # Backtest Daily Rebal

# %%
daily_bt = Backtest(signal = sig, asset_returns = total_returns, tcost = abs(total_returns*0), settings = settings)
daily_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(daily_bt)
# Out:
# Returns   : 0.07917564847859697
# Vol       : 0.11271639713501902
# SR        : 0.7024323921900665
# Max DD    : -30.47
#
# C Returns : 0.0754482941364543
# C SR      : 0.6298633643708482
# C Max DD  : -27.93
#
# Hit rate  : 0.534
# W | N | L : 0.53 | 0.02 | 0.46
# W/L Ratio : 1.14

# %%
get_returns_stats(daily_bt.asset_rtn, daily_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return    -0.974783    3.390635   -0.373865   -0.088664
# sharpe               -0.254302    0.632804   -0.050061   -0.083704
# dollar_sharpe        -0.288478     0.54053   -0.103859    -0.08888
# trade_sharpe         -0.329309    1.106339   -0.361672    0.173911
# long_sharpe          -0.373692   -0.424751   -0.470336   -0.178518
# short_sharpe         -0.279572    1.355658     0.80123    0.962385
# sortino               -0.11434    0.261153    -0.02237   -0.020795
# max_drawdown        -38.316444  -15.089643  -40.458027   -4.669352
# max_drawdown_start  2002-03-26  2009-09-07  2002-04-08  2010-06-03
# max_drawdown_end    2014-07-23  2010-02-04  2011-02-09  2016-11-08
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     1.625561     0.16581    0.693735     0.04505    2.757478
# sharpe                0.842651    0.068043    0.295169    0.026917    0.413698
# dollar_sharpe          0.85156    0.054574    0.279772    0.019364    0.273244
# trade_sharpe          0.834628   -0.212796    0.210037    0.300135    0.444568
# long_sharpe           0.504071    -0.54974   -0.885975   -0.094563    2.227841
# short_sharpe          1.949847   -0.303858     0.42115    1.603602    0.867069
# sortino               0.264244    0.023285    0.084961    0.006016     0.09179
# max_drawdown         -3.482391  -13.542316   -6.603901   -8.173247  -31.393718
# max_drawdown_start  2010-04-09  2011-08-01  2008-08-06  2006-12-28  2013-11-19
# max_drawdown_end    2010-07-22  2013-09-04  2008-11-20  2007-06-05  2016-11-23

# %%
plot_bt(daily_bt)

# %% [markdown]
# # Backtest Weekly Rebal

# %%
weekly_bt = Backtest(signal = sig, 
             asset_returns = total_returns, 
             tcost = abs(total_returns*0), 
             settings = settings,
             settings_inject = {"rebalance_period":"friday"})
weekly_bt.run()
# Out:
# Re-arranging asset columns
# Asset scaling ...
# Portfolio scaling ...
#     Grouping by [ALL]

# %%
get_summary(weekly_bt)
# Out:
# Returns   : 0.09303658905157235
# Vol       : 0.1128979132345231
# SR        : 0.8240771364684768
# Max DD    : -32.97
#
# C Returns : 0.0904518233910656
# C SR      : 0.7198221994699505
# C Max DD  : -29.59
#
# Hit rate  : 0.537
# W | N | L : 0.53 | 0.02 | 0.45
# W/L Ratio : 1.16

# %%
get_returns_stats(weekly_bt.asset_rtn, weekly_bt.wts)
# Out:
#                         USDSGD      USDTHB      USDTWD      USDKRW  \
# annualized_return    -0.431928    3.073141    0.428673   -0.138438
# sharpe               -0.117866    0.576867     0.05765   -0.142548
# dollar_sharpe        -0.146169    0.523072    0.024782     -0.1487
# trade_sharpe          -0.23349    0.904077   -0.020881   -0.267225
# long_sharpe          -0.325379   -3.179968   -0.066806    -0.40773
# short_sharpe          0.445373     1.48903    0.595981   -0.850724
# sortino              -0.052991    0.226861    0.026101   -0.033132
# max_drawdown         -25.90439  -18.067077  -46.316373    -5.00008
# max_drawdown_start  2002-03-26  2003-10-10  2002-03-07  2007-10-18
# max_drawdown_end    2008-04-22  2006-02-08  2003-09-23  2016-09-07
#
#                         USDPHP      USDINR      USDIDR      USDMYR      USDCNH
# annualized_return     1.070755    0.890463    0.152149    0.151905    3.307684
# sharpe                0.502328    0.365028    0.056178    0.078029    0.498655
# dollar_sharpe         0.495984       0.343    0.043364    0.067862    0.333705
# trade_sharpe          0.885782    0.442747    0.013099    0.302928    0.452087
# long_sharpe            1.80765    1.328825   -2.232023    0.167802   -0.162021
# short_sharpe          1.542603    0.579224     0.06743    1.584261     0.96377
# sortino               0.143243    0.131386    0.015575    0.019199    0.111525
# max_drawdown          -5.98957   -6.534721   -9.001247    -7.56857  -26.987796
# max_drawdown_start  2010-04-26  2011-08-01  2008-08-05  2011-05-05  2014-11-18
# max_drawdown_end    2010-08-24  2011-11-10  2010-05-06  2012-09-26  2016-10-28

# %%
plot_bt(weekly_bt)

# %% [markdown]
# # Daily vs Weekly

# %%
gen_plot_rtn(pd.concat([daily_bt.model_rtn.rename("daily"), weekly_bt.model_rtn.rename("weekly")], axis=1), main = "Daily vs Weekly Rebal")
# Out:
# <AxesSubplot:title={'center':'Daily vs Weekly Rebal'}, xlabel='Dates', ylabel='Cumulative returns'>

# %%
# pickle.dump(daily_bt, open("../BT/carry_tovol_asia_daily.p", "wb"))
# daily_bt = pickle.load(open("../BT/carry_tovol_asia_daily.p", "rb"))

# pickle.dump(weekly_bt, open("../BT/carry_tovol_asia_weekly.p", "wb"))
# weekly_bt = pickle.load(open("../BT/carry_tovol_asia_weekly.p", "rb"))

# %% [markdown]
# # Regime Plot

# %% [markdown]
# # Sensitivity Analysis

# %%
# pf.plot_monthly_returns_dist(bt_obj.model_rtn)
