# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# # Total Returns

# %%
total_returns_ori.pipe(fill_date).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5635 entries, 2000-01-03 to 2021-08-06
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AUDUSD  5634 non-null   float64
#  1   USDCAD  5634 non-null   float64
#  2   USDCHF  5634 non-null   float64
#  3   USDCNY  5580 non-null   float64
#  4   EURUSD  5634 non-null   float64
#  5   GBPUSD  5634 non-null   float64
#  6   USDINR  5632 non-null   float64
#  7   USDJPY  5634 non-null   float64
#  8   USDKRW  5634 non-null   float64
#  9   USDNOK  5634 non-null   float64
#  10  NZDUSD  5634 non-null   float64
#  11  USDPHP  5634 non-null   float64
#  12  USDSEK  5634 non-null   float64
#  13  USDSGD  5634 non-null   float64
#  14  USDTHB  5634 non-null   float64
#  15  USDTWD  5629 non-null   float64
#  16  USDIDR  5315 non-null   float64
#  17  USDMYR  4403 non-null   float64
#  18  USDCNH  2859 non-null   float64
# dtypes: float64(19)
# memory usage: 880.5 KB

# %%
msmx(total_returns_ori)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Asian Spot NDF

# %%
ndf.pipe(fill_date)[["USDIDR", "USDINR", "USDMYR", "USDTWD", "USDKRW", "USDPHP"]].pipe(fill_date).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5635 entries, 2000-01-03 to 2021-08-06
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   USDIDR  4239 non-null   float64
#  1   USDINR  5163 non-null   float64
#  2   USDMYR  4218 non-null   float64
#  3   USDTWD  5600 non-null   float64
#  4   USDKRW  5173 non-null   float64
#  5   USDPHP  5259 non-null   float64
# dtypes: float64(6)
# memory usage: 308.2 KB

# %%
### forward points
msmx(ndf.pipe(fill_date)[["USDIDR", "USDINR", "USDMYR", "USDTWD", "USDKRW", "USDPHP"]])
# Out:
# <AxesSubplot:>

# %%
### NDF data
msmx(spot_ndf.pipe(fill_date)[ASIA_FX])
# Out:
# <AxesSubplot:>

# %%
msmx(dirty_spot.pipe(fill_date)[ASIA_FX])
# Out:
# <AxesSubplot:>

# %%
msmx(spot.pipe(fill_date)[ASIA_FX])
# Out:
# <AxesSubplot:>

# %%
msmx(carry_returns_usd[ALL_FX])
# Out:
# <AxesSubplot:>

# %%
### Final spot, wasted data
msmx(spot_price_usd.pipe(fill_date)[["USDCNH", "USDSGD", "USDTHB", "USDIDR", "USDINR", "USDMYR", "USDTWD", "USDKRW", "USDPHP"]])
# Out:
# <AxesSubplot:>
