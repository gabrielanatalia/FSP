# %%
import sys
sys.path.insert(1, '../')
from genesis import *
# Out:
# C:\Users\vin_s\AppData\Local\Programs\Python\Python39\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
bt_obj = pickle.load(open("../BT/rx_skew_all.p", "rb"))

# %% [markdown]
# # Full Backtest

# %%
plot_bt(bt_obj)

# %%
gen_rolling_sharpe(bt_obj.model_rtn)
# Out:
# <AxesSubplot:title={'center':'1Y Rolling Sharpe, Average = 0.55'}, ylabel='Sharpe ratio'>

# %%
pf.plot_monthly_returns_dist(bt_obj.model_rtn)
# Out:
# <AxesSubplot:title={'center':'Distribution of monthly returns'}, xlabel='Returns', ylabel='Number of months'>

# %%
pf.plot_monthly_returns_heatmap(bt_obj.model_rtn)
# Out:
# <AxesSubplot:title={'center':'Monthly returns (%)'}, xlabel='Month', ylabel='Year'>

# %%
gen_rtn_col_longshort(bt_obj)

# %%
gen_rtn_col_component(bt_obj=bt_obj, 
                      spot_rtn = spot_returns_usd.loc[:bt_obj.model_rtn.index[-1], bt_obj.wts.columns], 
                      carry_rtn = carry_returns_usd.loc[:bt_obj.model_rtn.index[-1], bt_obj.wts.columns], 
                      compound=True)

# %% [markdown]
# # Regimes

# %%
### Regimes data option: `gfc_regime`, `rates_regime`, `vol_regime`, `cycle_regime`, `macro_regime`
full_regime_plot(bt_obj, rates_regime)

# %%
full_regime_plot(bt_obj, gfc_regime)
